# %%
# Dependencies
import json
import requests
from config import api_key
import pprint

# %%
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
city = "Minneapolis"
state = "MN"
# Build query URL
query_url = url + "appid=" + api_key + "&q=" + city

# %%
# Get weather data
weather_response = requests.get(query_url)
weather_json = weather_response.json()

# Get the temperature from the response
print(f"The weather API responded with: {weather_json}.")
# Out:
# The weather API responded with: {'coord': {'lon': -93.2638, 'lat': 44.98}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 287.06, 'feels_like': 286.8, 'temp_min': 284.35, 'temp_max': 288.65, 'pressure': 1013, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 0.45, 'deg': 250, 'gust': 1.34}, 'clouds': {'all': 40}, 'dt': 1630846117, 'sys': {'type': 2, 'id': 2008025, 'country': 'US', 'sunrise': 1630842021, 'sunset': 1630889001}, 'timezone': -18000, 'id': 5037649, 'name': 'Minneapolis', 'cod': 200}.

# %%
forecast_url = f'http://api.openweathermap.org/data/2.5/forecast?q={city},&appid={api_key}'

# %%
# Get weather data
weather_response = requests.get(forecast_url)
weather_json = weather_response.json()

# Get the temperature from the response
print(f"The weather API responded with: {pprint.pprint(weather_json)}.")
# Out:
# {'city': {'coord': {'lat': 44.98, 'lon': -93.2638},
#           'country': 'US',
#           'id': 5037649,
#           'name': 'Minneapolis',
#           'population': 382578,
#           'sunrise': 1630842021,
#           'sunset': 1630889001,
#           'timezone': -18000},
#  'cnt': 40,
#  'cod': '200',
#  'list': [{'clouds': {'all': 39},
#            'dt': 1630854000,
#            'dt_txt': '2021-09-05 15:00:00',
#            'main': {'feels_like': 288.45,
#                     'grnd_level': 983,
#                     'humidity': 76,
#                     'pressure': 1012,
#                     'sea_level': 1012,
#                     'temp': 288.84,
#                     'temp_kf': -3.54,
#                     'temp_max': 292.38,
#                     'temp_min': 288.84},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'scattered clouds',
#                         'icon': '03d',
#                         'id': 802,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 308, 'gust': 4.45, 'speed': 2.45}},
#           {'clouds': {'all': 26},
#            'dt': 1630864800,
#            'dt_txt': '2021-09-05 18:00:00',
#            'main': {'feels_like': 293.11,
#                     'grnd_level': 982,
#                     'humidity': 54,
#                     'pressure': 1011,
#                     'sea_level': 1011,
#                     'temp': 293.6,
#                     'temp_kf': -3.27,
#                     'temp_max': 296.87,
#                     'temp_min': 293.6},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'scattered clouds',
#                         'icon': '03d',
#                         'id': 802,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 290, 'gust': 7.2, 'speed': 3.98}},
#           {'clouds': {'all': 0},
#            'dt': 1630875600,
#            'dt_txt': '2021-09-05 21:00:00',
#            'main': {'feels_like': 297.6,
#                     'grnd_level': 981,
#                     'humidity': 32,
#                     'pressure': 1009,
#                     'sea_level': 1009,
#                     'temp': 298.2,
#                     'temp_kf': 0,
#                     'temp_max': 298.2,
#                     'temp_min': 298.2},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'clear sky',
#                         'icon': '01d',
#                         'id': 800,
#                         'main': 'Clear'}],
#            'wind': {'deg': 295, 'gust': 9.04, 'speed': 5.8}},
#           {'clouds': {'all': 16},
#            'dt': 1630886400,
#            'dt_txt': '2021-09-06 00:00:00',
#            'main': {'feels_like': 294.56,
#                     'grnd_level': 981,
#                     'humidity': 42,
#                     'pressure': 1010,
#                     'sea_level': 1010,
#                     'temp': 295.2,
#                     'temp_kf': 0,
#                     'temp_max': 295.2,
#                     'temp_min': 295.2},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'few clouds',
#                         'icon': '02d',
#                         'id': 801,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 303, 'gust': 7.43, 'speed': 4.54}},
#           {'clouds': {'all': 97},
#            'dt': 1630897200,
#            'dt_txt': '2021-09-06 03:00:00',
#            'main': {'feels_like': 291.2,
#                     'grnd_level': 983,
#                     'humidity': 53,
#                     'pressure': 1012,
#                     'sea_level': 1012,
#                     'temp': 291.89,
#                     'temp_kf': 0,
#                     'temp_max': 291.89,
#                     'temp_min': 291.89},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04n',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 300, 'gust': 8.84, 'speed': 3.15}},
#           {'clouds': {'all': 95},
#            'dt': 1630908000,
#            'dt_txt': '2021-09-06 06:00:00',
#            'main': {'feels_like': 288.64,
#                     'grnd_level': 983,
#                     'humidity': 62,
#                     'pressure': 1013,
#                     'sea_level': 1013,
#                     'temp': 289.35,
#                     'temp_kf': 0,
#                     'temp_max': 289.35,
#                     'temp_min': 289.35},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04n',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 347, 'gust': 2.05, 'speed': 1.23}},
#           {'clouds': {'all': 52},
#            'dt': 1630918800,
#            'dt_txt': '2021-09-06 09:00:00',
#            'main': {'feels_like': 287.29,
#                     'grnd_level': 983,
#                     'humidity': 64,
#                     'pressure': 1013,
#                     'sea_level': 1013,
#                     'temp': 288.07,
#                     'temp_kf': 0,
#                     'temp_max': 288.07,
#                     'temp_min': 288.07},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'broken clouds',
#                         'icon': '04n',
#                         'id': 803,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 115, 'gust': 1.12, 'speed': 0.87}},
#           {'clouds': {'all': 63},
#            'dt': 1630929600,
#            'dt_txt': '2021-09-06 12:00:00',
#            'main': {'feels_like': 286.63,
#                     'grnd_level': 984,
#                     'humidity': 69,
#                     'pressure': 1013,
#                     'sea_level': 1013,
#                     'temp': 287.35,
#                     'temp_kf': 0,
#                     'temp_max': 287.35,
#                     'temp_min': 287.35},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'broken clouds',
#                         'icon': '04d',
#                         'id': 803,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 173, 'gust': 1.32, 'speed': 1.08}},
#           {'clouds': {'all': 40},
#            'dt': 1630940400,
#            'dt_txt': '2021-09-06 15:00:00',
#            'main': {'feels_like': 292.39,
#                     'grnd_level': 984,
#                     'humidity': 50,
#                     'pressure': 1013,
#                     'sea_level': 1013,
#                     'temp': 293.04,
#                     'temp_kf': 0,
#                     'temp_max': 293.04,
#                     'temp_min': 293.04},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'scattered clouds',
#                         'icon': '03d',
#                         'id': 802,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 180, 'gust': 2.35, 'speed': 1.67}},
#           {'clouds': {'all': 40},
#            'dt': 1630951200,
#            'dt_txt': '2021-09-06 18:00:00',
#            'main': {'feels_like': 298.25,
#                     'grnd_level': 982,
#                     'humidity': 35,
#                     'pressure': 1011,
#                     'sea_level': 1011,
#                     'temp': 298.72,
#                     'temp_kf': 0,
#                     'temp_max': 298.72,
#                     'temp_min': 298.72},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'scattered clouds',
#                         'icon': '03d',
#                         'id': 802,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 171, 'gust': 3.55, 'speed': 2.59}},
#           {'clouds': {'all': 60},
#            'dt': 1630962000,
#            'dt_txt': '2021-09-06 21:00:00',
#            'main': {'feels_like': 300.26,
#                     'grnd_level': 980,
#                     'humidity': 33,
#                     'pressure': 1008,
#                     'sea_level': 1008,
#                     'temp': 300.97,
#                     'temp_kf': 0,
#                     'temp_max': 300.97,
#                     'temp_min': 300.97},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'broken clouds',
#                         'icon': '04d',
#                         'id': 803,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 173, 'gust': 5.98, 'speed': 4.75}},
#           {'clouds': {'all': 33},
#            'dt': 1630972800,
#            'dt_txt': '2021-09-07 00:00:00',
#            'main': {'feels_like': 297.78,
#                     'grnd_level': 978,
#                     'humidity': 51,
#                     'pressure': 1007,
#                     'sea_level': 1007,
#                     'temp': 297.92,
#                     'temp_kf': 0,
#                     'temp_max': 297.92,
#                     'temp_min': 297.92},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'scattered clouds',
#                         'icon': '03d',
#                         'id': 802,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 171, 'gust': 8.47, 'speed': 4.69}},
#           {'clouds': {'all': 60},
#            'dt': 1630983600,
#            'dt_txt': '2021-09-07 03:00:00',
#            'main': {'feels_like': 294.45,
#                     'grnd_level': 976,
#                     'humidity': 72,
#                     'pressure': 1005,
#                     'sea_level': 1005,
#                     'temp': 294.39,
#                     'temp_kf': 0,
#                     'temp_max': 294.39,
#                     'temp_min': 294.39},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'broken clouds',
#                         'icon': '04n',
#                         'id': 803,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 167, 'gust': 13.66, 'speed': 4.55}},
#           {'clouds': {'all': 64},
#            'dt': 1630994400,
#            'dt_txt': '2021-09-07 06:00:00',
#            'main': {'feels_like': 295.01,
#                     'grnd_level': 973,
#                     'humidity': 72,
#                     'pressure': 1002,
#                     'sea_level': 1002,
#                     'temp': 294.9,
#                     'temp_kf': 0,
#                     'temp_max': 294.9,
#                     'temp_min': 294.9},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'broken clouds',
#                         'icon': '04n',
#                         'id': 803,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 181, 'gust': 15.67, 'speed': 4.82}},
#           {'clouds': {'all': 100},
#            'dt': 1631005200,
#            'dt_txt': '2021-09-07 09:00:00',
#            'main': {'feels_like': 295.91,
#                     'grnd_level': 971,
#                     'humidity': 61,
#                     'pressure': 1000,
#                     'sea_level': 1000,
#                     'temp': 295.98,
#                     'temp_kf': 0,
#                     'temp_max': 295.98,
#                     'temp_min': 295.98},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04n',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 228, 'gust': 15.61, 'speed': 4.8}},
#           {'clouds': {'all': 100},
#            'dt': 1631016000,
#            'dt_txt': '2021-09-07 12:00:00',
#            'main': {'feels_like': 294.27,
#                     'grnd_level': 971,
#                     'humidity': 62,
#                     'pressure': 1000,
#                     'sea_level': 1000,
#                     'temp': 294.46,
#                     'temp_kf': 0,
#                     'temp_max': 294.46,
#                     'temp_min': 294.46},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04d',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 274, 'gust': 11.69, 'speed': 4.72}},
#           {'clouds': {'all': 66},
#            'dt': 1631026800,
#            'dt_txt': '2021-09-07 15:00:00',
#            'main': {'feels_like': 293.25,
#                     'grnd_level': 974,
#                     'humidity': 56,
#                     'pressure': 1003,
#                     'sea_level': 1003,
#                     'temp': 293.68,
#                     'temp_kf': 0,
#                     'temp_max': 293.68,
#                     'temp_min': 293.68},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'broken clouds',
#                         'icon': '04d',
#                         'id': 803,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 304, 'gust': 12.47, 'speed': 7.74}},
#           {'clouds': {'all': 54},
#            'dt': 1631037600,
#            'dt_txt': '2021-09-07 18:00:00',
#            'main': {'feels_like': 294.16,
#                     'grnd_level': 976,
#                     'humidity': 50,
#                     'pressure': 1005,
#                     'sea_level': 1005,
#                     'temp': 294.65,
#                     'temp_kf': 0,
#                     'temp_max': 294.65,
#                     'temp_min': 294.65},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'broken clouds',
#                         'icon': '04d',
#                         'id': 803,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 310, 'gust': 14.4, 'speed': 6.94}},
#           {'clouds': {'all': 63},
#            'dt': 1631048400,
#            'dt_txt': '2021-09-07 21:00:00',
#            'main': {'feels_like': 295.9,
#                     'grnd_level': 977,
#                     'humidity': 42,
#                     'pressure': 1005,
#                     'sea_level': 1005,
#                     'temp': 296.42,
#                     'temp_kf': 0,
#                     'temp_max': 296.42,
#                     'temp_min': 296.42},
#            'pop': 0.26,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'broken clouds',
#                         'icon': '04d',
#                         'id': 803,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 312, 'gust': 14.51, 'speed': 8.08}},
#           {'clouds': {'all': 51},
#            'dt': 1631059200,
#            'dt_txt': '2021-09-08 00:00:00',
#            'main': {'feels_like': 292.68,
#                     'grnd_level': 979,
#                     'humidity': 50,
#                     'pressure': 1008,
#                     'sea_level': 1008,
#                     'temp': 293.3,
#                     'temp_kf': 0,
#                     'temp_max': 293.3,
#                     'temp_min': 293.3},
#            'pop': 0.19,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'broken clouds',
#                         'icon': '04d',
#                         'id': 803,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 317, 'gust': 14.5, 'speed': 6.27}},
#           {'clouds': {'all': 49},
#            'dt': 1631070000,
#            'dt_txt': '2021-09-08 03:00:00',
#            'main': {'feels_like': 290.75,
#                     'grnd_level': 980,
#                     'humidity': 62,
#                     'pressure': 1009,
#                     'sea_level': 1009,
#                     'temp': 291.26,
#                     'temp_kf': 0,
#                     'temp_max': 291.26,
#                     'temp_min': 291.26},
#            'pop': 0.2,
#            'rain': {'3h': 0.11},
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'light rain',
#                         'icon': '10n',
#                         'id': 500,
#                         'main': 'Rain'}],
#            'wind': {'deg': 289, 'gust': 9.94, 'speed': 3.35}},
#           {'clouds': {'all': 33},
#            'dt': 1631080800,
#            'dt_txt': '2021-09-08 06:00:00',
#            'main': {'feels_like': 289.19,
#                     'grnd_level': 979,
#                     'humidity': 53,
#                     'pressure': 1009,
#                     'sea_level': 1009,
#                     'temp': 290.06,
#                     'temp_kf': 0,
#                     'temp_max': 290.06,
#                     'temp_min': 290.06},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'scattered clouds',
#                         'icon': '03n',
#                         'id': 802,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 292, 'gust': 12.83, 'speed': 4.59}},
#           {'clouds': {'all': 61},
#            'dt': 1631091600,
#            'dt_txt': '2021-09-08 09:00:00',
#            'main': {'feels_like': 288.79,
#                     'grnd_level': 980,
#                     'humidity': 51,
#                     'pressure': 1009,
#                     'sea_level': 1009,
#                     'temp': 289.74,
#                     'temp_kf': 0,
#                     'temp_max': 289.74,
#                     'temp_min': 289.74},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'broken clouds',
#                         'icon': '04n',
#                         'id': 803,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 300, 'gust': 12.96, 'speed': 4.79}},
#           {'clouds': {'all': 38},
#            'dt': 1631102400,
#            'dt_txt': '2021-09-08 12:00:00',
#            'main': {'feels_like': 287.53,
#                     'grnd_level': 981,
#                     'humidity': 54,
#                     'pressure': 1011,
#                     'sea_level': 1011,
#                     'temp': 288.53,
#                     'temp_kf': 0,
#                     'temp_max': 288.53,
#                     'temp_min': 288.53},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'scattered clouds',
#                         'icon': '03d',
#                         'id': 802,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 299, 'gust': 12.75, 'speed': 4.91}},
#           {'clouds': {'all': 2},
#            'dt': 1631113200,
#            'dt_txt': '2021-09-08 15:00:00',
#            'main': {'feels_like': 291.93,
#                     'grnd_level': 982,
#                     'humidity': 48,
#                     'pressure': 1011,
#                     'sea_level': 1011,
#                     'temp': 292.67,
#                     'temp_kf': 0,
#                     'temp_max': 292.67,
#                     'temp_min': 292.67},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'clear sky',
#                         'icon': '01d',
#                         'id': 800,
#                         'main': 'Clear'}],
#            'wind': {'deg': 316, 'gust': 11.3, 'speed': 5.95}},
#           {'clouds': {'all': 1},
#            'dt': 1631124000,
#            'dt_txt': '2021-09-08 18:00:00',
#            'main': {'feels_like': 296.23,
#                     'grnd_level': 982,
#                     'humidity': 35,
#                     'pressure': 1011,
#                     'sea_level': 1011,
#                     'temp': 296.89,
#                     'temp_kf': 0,
#                     'temp_max': 296.89,
#                     'temp_min': 296.89},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'clear sky',
#                         'icon': '01d',
#                         'id': 800,
#                         'main': 'Clear'}],
#            'wind': {'deg': 311, 'gust': 10.01, 'speed': 6.64}},
#           {'clouds': {'all': 17},
#            'dt': 1631134800,
#            'dt_txt': '2021-09-08 21:00:00',
#            'main': {'feels_like': 297.53,
#                     'grnd_level': 981,
#                     'humidity': 31,
#                     'pressure': 1010,
#                     'sea_level': 1010,
#                     'temp': 298.16,
#                     'temp_kf': 0,
#                     'temp_max': 298.16,
#                     'temp_min': 298.16},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'few clouds',
#                         'icon': '02d',
#                         'id': 801,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 309, 'gust': 9.96, 'speed': 6.75}},
#           {'clouds': {'all': 55},
#            'dt': 1631145600,
#            'dt_txt': '2021-09-09 00:00:00',
#            'main': {'feels_like': 294.26,
#                     'grnd_level': 982,
#                     'humidity': 40,
#                     'pressure': 1011,
#                     'sea_level': 1011,
#                     'temp': 294.98,
#                     'temp_kf': 0,
#                     'temp_max': 294.98,
#                     'temp_min': 294.98},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'broken clouds',
#                         'icon': '04d',
#                         'id': 803,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 313, 'gust': 8.96, 'speed': 5.21}},
#           {'clouds': {'all': 18},
#            'dt': 1631156400,
#            'dt_txt': '2021-09-09 03:00:00',
#            'main': {'feels_like': 290.71,
#                     'grnd_level': 983,
#                     'humidity': 51,
#                     'pressure': 1012,
#                     'sea_level': 1012,
#                     'temp': 291.49,
#                     'temp_kf': 0,
#                     'temp_max': 291.49,
#                     'temp_min': 291.49},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'few clouds',
#                         'icon': '02n',
#                         'id': 801,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 301, 'gust': 8.5, 'speed': 2.67}},
#           {'clouds': {'all': 10},
#            'dt': 1631167200,
#            'dt_txt': '2021-09-09 06:00:00',
#            'main': {'feels_like': 288.12,
#                     'grnd_level': 983,
#                     'humidity': 60,
#                     'pressure': 1013,
#                     'sea_level': 1013,
#                     'temp': 288.92,
#                     'temp_kf': 0,
#                     'temp_max': 288.92,
#                     'temp_min': 288.92},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'clear sky',
#                         'icon': '01n',
#                         'id': 800,
#                         'main': 'Clear'}],
#            'wind': {'deg': 358, 'gust': 3.79, 'speed': 1.42}},
#           {'clouds': {'all': 81},
#            'dt': 1631178000,
#            'dt_txt': '2021-09-09 09:00:00',
#            'main': {'feels_like': 287.3,
#                     'grnd_level': 984,
#                     'humidity': 65,
#                     'pressure': 1013,
#                     'sea_level': 1013,
#                     'temp': 288.06,
#                     'temp_kf': 0,
#                     'temp_max': 288.06,
#                     'temp_min': 288.06},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'broken clouds',
#                         'icon': '04n',
#                         'id': 803,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 343, 'gust': 0.66, 'speed': 0.53}},
#           {'clouds': {'all': 90},
#            'dt': 1631188800,
#            'dt_txt': '2021-09-09 12:00:00',
#            'main': {'feels_like': 287.2,
#                     'grnd_level': 984,
#                     'humidity': 66,
#                     'pressure': 1014,
#                     'sea_level': 1014,
#                     'temp': 287.94,
#                     'temp_kf': 0,
#                     'temp_max': 287.94,
#                     'temp_min': 287.94},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04d',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 220, 'gust': 1.2, 'speed': 0.87}},
#           {'clouds': {'all': 90},
#            'dt': 1631199600,
#            'dt_txt': '2021-09-09 15:00:00',
#            'main': {'feels_like': 291.54,
#                     'grnd_level': 983,
#                     'humidity': 49,
#                     'pressure': 1013,
#                     'sea_level': 1013,
#                     'temp': 292.29,
#                     'temp_kf': 0,
#                     'temp_max': 292.29,
#                     'temp_min': 292.29},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04d',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 208, 'gust': 2.87, 'speed': 1.96}},
#           {'clouds': {'all': 68},
#            'dt': 1631210400,
#            'dt_txt': '2021-09-09 18:00:00',
#            'main': {'feels_like': 296.78,
#                     'grnd_level': 982,
#                     'humidity': 34,
#                     'pressure': 1011,
#                     'sea_level': 1011,
#                     'temp': 297.41,
#                     'temp_kf': 0,
#                     'temp_max': 297.41,
#                     'temp_min': 297.41},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'broken clouds',
#                         'icon': '04d',
#                         'id': 803,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 211, 'gust': 3.28, 'speed': 2.46}},
#           {'clouds': {'all': 74},
#            'dt': 1631221200,
#            'dt_txt': '2021-09-09 21:00:00',
#            'main': {'feels_like': 297.15,
#                     'grnd_level': 979,
#                     'humidity': 33,
#                     'pressure': 1008,
#                     'sea_level': 1008,
#                     'temp': 297.77,
#                     'temp_kf': 0,
#                     'temp_max': 297.77,
#                     'temp_min': 297.77},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'broken clouds',
#                         'icon': '04d',
#                         'id': 803,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 183, 'gust': 3.86, 'speed': 3.72}},
#           {'clouds': {'all': 86},
#            'dt': 1631232000,
#            'dt_txt': '2021-09-10 00:00:00',
#            'main': {'feels_like': 295.05,
#                     'grnd_level': 979,
#                     'humidity': 45,
#                     'pressure': 1008,
#                     'sea_level': 1008,
#                     'temp': 295.58,
#                     'temp_kf': 0,
#                     'temp_max': 295.58,
#                     'temp_min': 295.58},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04d',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 161, 'gust': 6.93, 'speed': 3.86}},
#           {'clouds': {'all': 90},
#            'dt': 1631242800,
#            'dt_txt': '2021-09-10 03:00:00',
#            'main': {'feels_like': 291.96,
#                     'grnd_level': 977,
#                     'humidity': 61,
#                     'pressure': 1006,
#                     'sea_level': 1006,
#                     'temp': 292.39,
#                     'temp_kf': 0,
#                     'temp_max': 292.39,
#                     'temp_min': 292.39},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04n',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 136, 'gust': 12.28, 'speed': 3.75}},
#           {'clouds': {'all': 95},
#            'dt': 1631253600,
#            'dt_txt': '2021-09-10 06:00:00',
#            'main': {'feels_like': 291.88,
#                     'grnd_level': 975,
#                     'humidity': 56,
#                     'pressure': 1004,
#                     'sea_level': 1004,
#                     'temp': 292.43,
#                     'temp_kf': 0,
#                     'temp_max': 292.43,
#                     'temp_min': 292.43},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04d',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 143, 'gust': 14.83, 'speed': 4.03}},
#           {'clouds': {'all': 100},
#            'dt': 1631264400,
#            'dt_txt': '2021-09-10 09:00:00',
#            'main': {'feels_like': 291.8,
#                     'grnd_level': 972,
#                     'humidity': 61,
#                     'pressure': 1001,
#                     'sea_level': 1001,
#                     'temp': 292.24,
#                     'temp_kf': 0,
#                     'temp_max': 292.24,
#                     'temp_min': 292.24},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04d',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 166, 'gust': 10.67, 'speed': 3.64}},
#           {'clouds': {'all': 78},
#            'dt': 1631275200,
#            'dt_txt': '2021-09-10 12:00:00',
#            'main': {'feels_like': 290.43,
#                     'grnd_level': 972,
#                     'humidity': 71,
#                     'pressure': 1001,
#                     'sea_level': 1001,
#                     'temp': 290.76,
#                     'temp_kf': 0,
#                     'temp_max': 290.76,
#                     'temp_min': 290.76},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'broken clouds',
#                         'icon': '04d',
#                         'id': 803,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 194, 'gust': 8.27, 'speed': 2.93}}],
#  'message': 0}
# The weather API responded with: None.
