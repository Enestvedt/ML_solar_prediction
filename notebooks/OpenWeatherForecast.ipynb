# %%
# Dependencies
import json
import requests
from config import api_key
import pprint

# %%
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
city = "Minneapolis"
state = "MN"
# Build query URL
query_url = url + "appid=" + api_key + "&q=" + city

# %%
# Get weather data
weather_response = requests.get(query_url)
weather_json = weather_response.json()

# Get the temperature from the response
print(f"The weather API responded with: {weather_json}.")
# Out:
# The weather API responded with: {'coord': {'lon': -93.2638, 'lat': 44.98}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 296.17, 'feels_like': 295.83, 'temp_min': 294.29, 'temp_max': 297.7, 'pressure': 1009, 'humidity': 50}, 'visibility': 10000, 'wind': {'speed': 1.34, 'deg': 103, 'gust': 5.36}, 'clouds': {'all': 20}, 'dt': 1631033156, 'sys': {'type': 2, 'id': 2008025, 'country': 'US', 'sunrise': 1631014963, 'sunset': 1631061576}, 'timezone': -18000, 'id': 5037649, 'name': 'Minneapolis', 'cod': 200}.

# %%
forecast_url = f'http://api.openweathermap.org/data/2.5/forecast?q={city},&appid={api_key}'

# %%
# Get weather data
weather_response = requests.get(forecast_url)
weather_json = weather_response.json()

# Get the temperature from the response
print(f"The weather API responded with: {pprint.pprint(weather_json)}.")
# Out:
# {'city': {'coord': {'lat': 44.98, 'lon': -93.2638},
#           'country': 'US',
#           'id': 5037649,
#           'name': 'Minneapolis',
#           'population': 382578,
#           'sunrise': 1631014963,
#           'sunset': 1631061576,
#           'timezone': -18000},
#  'cnt': 40,
#  'cod': '200',
#  'list': [{'clouds': {'all': 20},
#            'dt': 1631037600,
#            'dt_txt': '2021-09-07 18:00:00',
#            'main': {'feels_like': 295.84,
#                     'grnd_level': 979,
#                     'humidity': 50,
#                     'pressure': 1009,
#                     'sea_level': 1009,
#                     'temp': 296.18,
#                     'temp_kf': -1.2,
#                     'temp_max': 297.38,
#                     'temp_min': 296.18},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'few clouds',
#                         'icon': '02d',
#                         'id': 801,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 309, 'gust': 10.85, 'speed': 6.88}},
#           {'clouds': {'all': 14},
#            'dt': 1631048400,
#            'dt_txt': '2021-09-07 21:00:00',
#            'main': {'feels_like': 296.56,
#                     'grnd_level': 979,
#                     'humidity': 43,
#                     'pressure': 1008,
#                     'sea_level': 1008,
#                     'temp': 297,
#                     'temp_kf': -1.63,
#                     'temp_max': 298.63,
#                     'temp_min': 297},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'few clouds',
#                         'icon': '02d',
#                         'id': 801,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 312, 'gust': 10.73, 'speed': 6.8}},
#           {'clouds': {'all': 9},
#            'dt': 1631059200,
#            'dt_txt': '2021-09-08 00:00:00',
#            'main': {'feels_like': 295.44,
#                     'grnd_level': 979,
#                     'humidity': 41,
#                     'pressure': 1008,
#                     'sea_level': 1008,
#                     'temp': 296.03,
#                     'temp_kf': 0.08,
#                     'temp_max': 296.03,
#                     'temp_min': 295.95},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'clear sky',
#                         'icon': '01d',
#                         'id': 800,
#                         'main': 'Clear'}],
#            'wind': {'deg': 292, 'gust': 10.92, 'speed': 5.91}},
#           {'clouds': {'all': 31},
#            'dt': 1631070000,
#            'dt_txt': '2021-09-08 03:00:00',
#            'main': {'feels_like': 292.08,
#                     'grnd_level': 980,
#                     'humidity': 41,
#                     'pressure': 1009,
#                     'sea_level': 1009,
#                     'temp': 292.97,
#                     'temp_kf': 0,
#                     'temp_max': 292.97,
#                     'temp_min': 292.97},
#            'pop': 0.04,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'scattered clouds',
#                         'icon': '03n',
#                         'id': 802,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 291, 'gust': 11.87, 'speed': 4.83}},
#           {'clouds': {'all': 20},
#            'dt': 1631080800,
#            'dt_txt': '2021-09-08 06:00:00',
#            'main': {'feels_like': 289.31,
#                     'grnd_level': 980,
#                     'humidity': 52,
#                     'pressure': 1010,
#                     'sea_level': 1010,
#                     'temp': 290.19,
#                     'temp_kf': 0,
#                     'temp_max': 290.19,
#                     'temp_min': 290.19},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'few clouds',
#                         'icon': '02n',
#                         'id': 801,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 290, 'gust': 10.85, 'speed': 3.93}},
#           {'clouds': {'all': 4},
#            'dt': 1631091600,
#            'dt_txt': '2021-09-08 09:00:00',
#            'main': {'feels_like': 287.68,
#                     'grnd_level': 980,
#                     'humidity': 54,
#                     'pressure': 1010,
#                     'sea_level': 1010,
#                     'temp': 288.66,
#                     'temp_kf': 0,
#                     'temp_max': 288.66,
#                     'temp_min': 288.66},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'clear sky',
#                         'icon': '01n',
#                         'id': 800,
#                         'main': 'Clear'}],
#            'wind': {'deg': 301, 'gust': 12.15, 'speed': 4.23}},
#           {'clouds': {'all': 2},
#            'dt': 1631102400,
#            'dt_txt': '2021-09-08 12:00:00',
#            'main': {'feels_like': 286.94,
#                     'grnd_level': 982,
#                     'humidity': 59,
#                     'pressure': 1011,
#                     'sea_level': 1011,
#                     'temp': 287.87,
#                     'temp_kf': 0,
#                     'temp_max': 287.87,
#                     'temp_min': 287.87},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'clear sky',
#                         'icon': '01d',
#                         'id': 800,
#                         'main': 'Clear'}],
#            'wind': {'deg': 306, 'gust': 13.05, 'speed': 4.64}},
#           {'clouds': {'all': 0},
#            'dt': 1631113200,
#            'dt_txt': '2021-09-08 15:00:00',
#            'main': {'feels_like': 291.31,
#                     'grnd_level': 983,
#                     'humidity': 53,
#                     'pressure': 1012,
#                     'sea_level': 1012,
#                     'temp': 291.99,
#                     'temp_kf': 0,
#                     'temp_max': 291.99,
#                     'temp_min': 291.99},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'clear sky',
#                         'icon': '01d',
#                         'id': 800,
#                         'main': 'Clear'}],
#            'wind': {'deg': 318, 'gust': 10.8, 'speed': 5.66}},
#           {'clouds': {'all': 0},
#            'dt': 1631124000,
#            'dt_txt': '2021-09-08 18:00:00',
#            'main': {'feels_like': 295.29,
#                     'grnd_level': 983,
#                     'humidity': 38,
#                     'pressure': 1012,
#                     'sea_level': 1012,
#                     'temp': 295.96,
#                     'temp_kf': 0,
#                     'temp_max': 295.96,
#                     'temp_min': 295.96},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'clear sky',
#                         'icon': '01d',
#                         'id': 800,
#                         'main': 'Clear'}],
#            'wind': {'deg': 313, 'gust': 9.11, 'speed': 6.46}},
#           {'clouds': {'all': 25},
#            'dt': 1631134800,
#            'dt_txt': '2021-09-08 21:00:00',
#            'main': {'feels_like': 295.7,
#                     'grnd_level': 983,
#                     'humidity': 37,
#                     'pressure': 1011,
#                     'sea_level': 1011,
#                     'temp': 296.36,
#                     'temp_kf': 0,
#                     'temp_max': 296.36,
#                     'temp_min': 296.36},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'scattered clouds',
#                         'icon': '03d',
#                         'id': 802,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 325, 'gust': 9.28, 'speed': 7.86}},
#           {'clouds': {'all': 62},
#            'dt': 1631145600,
#            'dt_txt': '2021-09-09 00:00:00',
#            'main': {'feels_like': 292.71,
#                     'grnd_level': 983,
#                     'humidity': 41,
#                     'pressure': 1013,
#                     'sea_level': 1013,
#                     'temp': 293.54,
#                     'temp_kf': 0,
#                     'temp_max': 293.54,
#                     'temp_min': 293.54},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'broken clouds',
#                         'icon': '04d',
#                         'id': 803,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 324, 'gust': 10.93, 'speed': 4.59}},
#           {'clouds': {'all': 37},
#            'dt': 1631156400,
#            'dt_txt': '2021-09-09 03:00:00',
#            'main': {'feels_like': 289.48,
#                     'grnd_level': 985,
#                     'humidity': 51,
#                     'pressure': 1014,
#                     'sea_level': 1014,
#                     'temp': 290.37,
#                     'temp_kf': 0,
#                     'temp_max': 290.37,
#                     'temp_min': 290.37},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'scattered clouds',
#                         'icon': '03n',
#                         'id': 802,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 310, 'gust': 8.6, 'speed': 2.56}},
#           {'clouds': {'all': 20},
#            'dt': 1631167200,
#            'dt_txt': '2021-09-09 06:00:00',
#            'main': {'feels_like': 287.35,
#                     'grnd_level': 985,
#                     'humidity': 57,
#                     'pressure': 1015,
#                     'sea_level': 1015,
#                     'temp': 288.29,
#                     'temp_kf': 0,
#                     'temp_max': 288.29,
#                     'temp_min': 288.29},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'few clouds',
#                         'icon': '02n',
#                         'id': 801,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 308, 'gust': 7.65, 'speed': 2.61}},
#           {'clouds': {'all': 0},
#            'dt': 1631178000,
#            'dt_txt': '2021-09-09 09:00:00',
#            'main': {'feels_like': 286.02,
#                     'grnd_level': 986,
#                     'humidity': 64,
#                     'pressure': 1016,
#                     'sea_level': 1016,
#                     'temp': 286.92,
#                     'temp_kf': 0,
#                     'temp_max': 286.92,
#                     'temp_min': 286.92},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'clear sky',
#                         'icon': '01n',
#                         'id': 800,
#                         'main': 'Clear'}],
#            'wind': {'deg': 317, 'gust': 4.5, 'speed': 1.83}},
#           {'clouds': {'all': 3},
#            'dt': 1631188800,
#            'dt_txt': '2021-09-09 12:00:00',
#            'main': {'feels_like': 284.97,
#                     'grnd_level': 987,
#                     'humidity': 73,
#                     'pressure': 1017,
#                     'sea_level': 1017,
#                     'temp': 285.75,
#                     'temp_kf': 0,
#                     'temp_max': 285.75,
#                     'temp_min': 285.75},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'clear sky',
#                         'icon': '01d',
#                         'id': 800,
#                         'main': 'Clear'}],
#            'wind': {'deg': 328, 'gust': 3.69, 'speed': 1.53}},
#           {'clouds': {'all': 45},
#            'dt': 1631199600,
#            'dt_txt': '2021-09-09 15:00:00',
#            'main': {'feels_like': 290.21,
#                     'grnd_level': 988,
#                     'humidity': 60,
#                     'pressure': 1018,
#                     'sea_level': 1018,
#                     'temp': 290.82,
#                     'temp_kf': 0,
#                     'temp_max': 290.82,
#                     'temp_min': 290.82},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'scattered clouds',
#                         'icon': '03d',
#                         'id': 802,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 327, 'gust': 2.64, 'speed': 1.78}},
#           {'clouds': {'all': 31},
#            'dt': 1631210400,
#            'dt_txt': '2021-09-09 18:00:00',
#            'main': {'feels_like': 295,
#                     'grnd_level': 987,
#                     'humidity': 42,
#                     'pressure': 1016,
#                     'sea_level': 1016,
#                     'temp': 295.6,
#                     'temp_kf': 0,
#                     'temp_max': 295.6,
#                     'temp_min': 295.6},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'scattered clouds',
#                         'icon': '03d',
#                         'id': 802,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 313, 'gust': 3.05, 'speed': 2.31}},
#           {'clouds': {'all': 99},
#            'dt': 1631221200,
#            'dt_txt': '2021-09-09 21:00:00',
#            'main': {'feels_like': 296.62,
#                     'grnd_level': 985,
#                     'humidity': 35,
#                     'pressure': 1014,
#                     'sea_level': 1014,
#                     'temp': 297.24,
#                     'temp_kf': 0,
#                     'temp_max': 297.24,
#                     'temp_min': 297.24},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04d',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 304, 'gust': 1.65, 'speed': 1.46}},
#           {'clouds': {'all': 89},
#            'dt': 1631232000,
#            'dt_txt': '2021-09-10 00:00:00',
#            'main': {'feels_like': 294.29,
#                     'grnd_level': 985,
#                     'humidity': 43,
#                     'pressure': 1014,
#                     'sea_level': 1014,
#                     'temp': 294.93,
#                     'temp_kf': 0,
#                     'temp_max': 294.93,
#                     'temp_min': 294.93},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04d',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 288, 'gust': 1.22, 'speed': 1.04}},
#           {'clouds': {'all': 2},
#            'dt': 1631242800,
#            'dt_txt': '2021-09-10 03:00:00',
#            'main': {'feels_like': 291.18,
#                     'grnd_level': 986,
#                     'humidity': 51,
#                     'pressure': 1015,
#                     'sea_level': 1015,
#                     'temp': 291.92,
#                     'temp_kf': 0,
#                     'temp_max': 291.92,
#                     'temp_min': 291.92},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'clear sky',
#                         'icon': '01n',
#                         'id': 800,
#                         'main': 'Clear'}],
#            'wind': {'deg': 99, 'gust': 0.7, 'speed': 0.58}},
#           {'clouds': {'all': 3},
#            'dt': 1631253600,
#            'dt_txt': '2021-09-10 06:00:00',
#            'main': {'feels_like': 289.14,
#                     'grnd_level': 986,
#                     'humidity': 59,
#                     'pressure': 1015,
#                     'sea_level': 1015,
#                     'temp': 289.87,
#                     'temp_kf': 0,
#                     'temp_max': 289.87,
#                     'temp_min': 289.87},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'clear sky',
#                         'icon': '01n',
#                         'id': 800,
#                         'main': 'Clear'}],
#            'wind': {'deg': 137, 'gust': 2.74, 'speed': 1.8}},
#           {'clouds': {'all': 3},
#            'dt': 1631264400,
#            'dt_txt': '2021-09-10 09:00:00',
#            'main': {'feels_like': 287.64,
#                     'grnd_level': 985,
#                     'humidity': 68,
#                     'pressure': 1015,
#                     'sea_level': 1015,
#                     'temp': 288.29,
#                     'temp_kf': 0,
#                     'temp_max': 288.29,
#                     'temp_min': 288.29},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'clear sky',
#                         'icon': '01n',
#                         'id': 800,
#                         'main': 'Clear'}],
#            'wind': {'deg': 150, 'gust': 4.63, 'speed': 1.97}},
#           {'clouds': {'all': 4},
#            'dt': 1631275200,
#            'dt_txt': '2021-09-10 12:00:00',
#            'main': {'feels_like': 286.75,
#                     'grnd_level': 985,
#                     'humidity': 75,
#                     'pressure': 1015,
#                     'sea_level': 1015,
#                     'temp': 287.32,
#                     'temp_kf': 0,
#                     'temp_max': 287.32,
#                     'temp_min': 287.32},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'clear sky',
#                         'icon': '01d',
#                         'id': 800,
#                         'main': 'Clear'}],
#            'wind': {'deg': 152, 'gust': 7.8, 'speed': 2.61}},
#           {'clouds': {'all': 2},
#            'dt': 1631286000,
#            'dt_txt': '2021-09-10 15:00:00',
#            'main': {'feels_like': 293.12,
#                     'grnd_level': 985,
#                     'humidity': 51,
#                     'pressure': 1015,
#                     'sea_level': 1015,
#                     'temp': 293.68,
#                     'temp_kf': 0,
#                     'temp_max': 293.68,
#                     'temp_min': 293.68},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'clear sky',
#                         'icon': '01d',
#                         'id': 800,
#                         'main': 'Clear'}],
#            'wind': {'deg': 164, 'gust': 7.55, 'speed': 4.19}},
#           {'clouds': {'all': 12},
#            'dt': 1631296800,
#            'dt_txt': '2021-09-10 18:00:00',
#            'main': {'feels_like': 299.71,
#                     'grnd_level': 984,
#                     'humidity': 37,
#                     'pressure': 1012,
#                     'sea_level': 1012,
#                     'temp': 299.91,
#                     'temp_kf': 0,
#                     'temp_max': 299.91,
#                     'temp_min': 299.91},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'few clouds',
#                         'icon': '02d',
#                         'id': 801,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 188, 'gust': 7.34, 'speed': 4.79}},
#           {'clouds': {'all': 39},
#            'dt': 1631307600,
#            'dt_txt': '2021-09-10 21:00:00',
#            'main': {'feels_like': 300.44,
#                     'grnd_level': 981,
#                     'humidity': 40,
#                     'pressure': 1010,
#                     'sea_level': 1010,
#                     'temp': 300.7,
#                     'temp_kf': 0,
#                     'temp_max': 300.7,
#                     'temp_min': 300.7},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'scattered clouds',
#                         'icon': '03d',
#                         'id': 802,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 186, 'gust': 8.06, 'speed': 5.53}},
#           {'clouds': {'all': 22},
#            'dt': 1631318400,
#            'dt_txt': '2021-09-11 00:00:00',
#            'main': {'feels_like': 298.56,
#                     'grnd_level': 980,
#                     'humidity': 48,
#                     'pressure': 1008,
#                     'sea_level': 1008,
#                     'temp': 298.7,
#                     'temp_kf': 0,
#                     'temp_max': 298.7,
#                     'temp_min': 298.7},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'few clouds',
#                         'icon': '02d',
#                         'id': 801,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 168, 'gust': 9.34, 'speed': 4.56}},
#           {'clouds': {'all': 31},
#            'dt': 1631329200,
#            'dt_txt': '2021-09-11 03:00:00',
#            'main': {'feels_like': 295.19,
#                     'grnd_level': 979,
#                     'humidity': 66,
#                     'pressure': 1008,
#                     'sea_level': 1008,
#                     'temp': 295.21,
#                     'temp_kf': 0,
#                     'temp_max': 295.21,
#                     'temp_min': 295.21},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'scattered clouds',
#                         'icon': '03n',
#                         'id': 802,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 168, 'gust': 11.9, 'speed': 3.58}},
#           {'clouds': {'all': 23},
#            'dt': 1631340000,
#            'dt_txt': '2021-09-11 06:00:00',
#            'main': {'feels_like': 294.93,
#                     'grnd_level': 978,
#                     'humidity': 63,
#                     'pressure': 1007,
#                     'sea_level': 1007,
#                     'temp': 295.04,
#                     'temp_kf': 0,
#                     'temp_max': 295.04,
#                     'temp_min': 295.04},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'few clouds',
#                         'icon': '02n',
#                         'id': 801,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 194, 'gust': 13.3, 'speed': 4.17}},
#           {'clouds': {'all': 71},
#            'dt': 1631350800,
#            'dt_txt': '2021-09-11 09:00:00',
#            'main': {'feels_like': 293.3,
#                     'grnd_level': 979,
#                     'humidity': 66,
#                     'pressure': 1008,
#                     'sea_level': 1008,
#                     'temp': 293.49,
#                     'temp_kf': 0,
#                     'temp_max': 293.49,
#                     'temp_min': 293.49},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'broken clouds',
#                         'icon': '04n',
#                         'id': 803,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 234, 'gust': 10.14, 'speed': 2.67}},
#           {'clouds': {'all': 84},
#            'dt': 1631361600,
#            'dt_txt': '2021-09-11 12:00:00',
#            'main': {'feels_like': 293.34,
#                     'grnd_level': 979,
#                     'humidity': 70,
#                     'pressure': 1008,
#                     'sea_level': 1008,
#                     'temp': 293.43,
#                     'temp_kf': 0,
#                     'temp_max': 293.43,
#                     'temp_min': 293.43},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'broken clouds',
#                         'icon': '04d',
#                         'id': 803,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 263, 'gust': 7.6, 'speed': 2.15}},
#           {'clouds': {'all': 97},
#            'dt': 1631372400,
#            'dt_txt': '2021-09-11 15:00:00',
#            'main': {'feels_like': 296.18,
#                     'grnd_level': 980,
#                     'humidity': 56,
#                     'pressure': 1009,
#                     'sea_level': 1009,
#                     'temp': 296.34,
#                     'temp_kf': 0,
#                     'temp_max': 296.34,
#                     'temp_min': 296.34},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04d',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 19, 'gust': 7.86, 'speed': 4.67}},
#           {'clouds': {'all': 93},
#            'dt': 1631383200,
#            'dt_txt': '2021-09-11 18:00:00',
#            'main': {'feels_like': 296.31,
#                     'grnd_level': 982,
#                     'humidity': 52,
#                     'pressure': 1011,
#                     'sea_level': 1011,
#                     'temp': 296.56,
#                     'temp_kf': 0,
#                     'temp_max': 296.56,
#                     'temp_min': 296.56},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04d',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 334, 'gust': 6.19, 'speed': 6}},
#           {'clouds': {'all': 39},
#            'dt': 1631394000,
#            'dt_txt': '2021-09-11 21:00:00',
#            'main': {'feels_like': 295.53,
#                     'grnd_level': 983,
#                     'humidity': 35,
#                     'pressure': 1012,
#                     'sea_level': 1012,
#                     'temp': 296.25,
#                     'temp_kf': 0,
#                     'temp_max': 296.25,
#                     'temp_min': 296.25},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'scattered clouds',
#                         'icon': '03d',
#                         'id': 802,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 333, 'gust': 7.34, 'speed': 5.12}},
#           {'clouds': {'all': 69},
#            'dt': 1631404800,
#            'dt_txt': '2021-09-12 00:00:00',
#            'main': {'feels_like': 292.63,
#                     'grnd_level': 985,
#                     'humidity': 36,
#                     'pressure': 1014,
#                     'sea_level': 1014,
#                     'temp': 293.59,
#                     'temp_kf': 0,
#                     'temp_max': 293.59,
#                     'temp_min': 293.59},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'broken clouds',
#                         'icon': '04d',
#                         'id': 803,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 359, 'gust': 7.03, 'speed': 3.86}},
#           {'clouds': {'all': 85},
#            'dt': 1631415600,
#            'dt_txt': '2021-09-12 03:00:00',
#            'main': {'feels_like': 288.39,
#                     'grnd_level': 987,
#                     'humidity': 41,
#                     'pressure': 1017,
#                     'sea_level': 1017,
#                     'temp': 289.62,
#                     'temp_kf': 0,
#                     'temp_max': 289.62,
#                     'temp_min': 289.62},
#            'pop': 0,
#            'sys': {'pod': 'n'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04n',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 357, 'gust': 8.34, 'speed': 2.99}},
#           {'clouds': {'all': 43},
#            'dt': 1631426400,
#            'dt_txt': '2021-09-12 06:00:00',
#            'main': {'feels_like': 285.57,
#                     'grnd_level': 989,
#                     'humidity': 47,
#                     'pressure': 1019,
#                     'sea_level': 1019,
#                     'temp': 286.91,
#                     'temp_kf': 0,
#                     'temp_max': 286.91,
#                     'temp_min': 286.91},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'scattered clouds',
#                         'icon': '03d',
#                         'id': 802,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 358, 'gust': 9.74, 'speed': 3.55}},
#           {'clouds': {'all': 3},
#            'dt': 1631437200,
#            'dt_txt': '2021-09-12 09:00:00',
#            'main': {'feels_like': 282.63,
#                     'grnd_level': 989,
#                     'humidity': 55,
#                     'pressure': 1020,
#                     'sea_level': 1020,
#                     'temp': 284.05,
#                     'temp_kf': 0,
#                     'temp_max': 284.05,
#                     'temp_min': 284.05},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'clear sky',
#                         'icon': '01d',
#                         'id': 800,
#                         'main': 'Clear'}],
#            'wind': {'deg': 34, 'gust': 5.7, 'speed': 2.62}},
#           {'clouds': {'all': 42},
#            'dt': 1631448000,
#            'dt_txt': '2021-09-12 12:00:00',
#            'main': {'feels_like': 281.6,
#                     'grnd_level': 990,
#                     'humidity': 60,
#                     'pressure': 1021,
#                     'sea_level': 1021,
#                     'temp': 282.55,
#                     'temp_kf': 0,
#                     'temp_max': 282.55,
#                     'temp_min': 282.55},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'scattered clouds',
#                         'icon': '03d',
#                         'id': 802,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 34, 'gust': 4.18, 'speed': 2.05}},
#           {'clouds': {'all': 99},
#            'dt': 1631458800,
#            'dt_txt': '2021-09-12 15:00:00',
#            'main': {'feels_like': 284.23,
#                     'grnd_level': 991,
#                     'humidity': 51,
#                     'pressure': 1022,
#                     'sea_level': 1022,
#                     'temp': 285.6,
#                     'temp_kf': 0,
#                     'temp_max': 285.6,
#                     'temp_min': 285.6},
#            'pop': 0,
#            'sys': {'pod': 'd'},
#            'visibility': 10000,
#            'weather': [{'description': 'overcast clouds',
#                         'icon': '04d',
#                         'id': 804,
#                         'main': 'Clouds'}],
#            'wind': {'deg': 25, 'gust': 3.03, 'speed': 2.38}}],
#  'message': 0}
# The weather API responded with: None.
